# %% [markdown]
# # <h1 align= 'center'>Mini Project on IPL Data-set</h1></font>

# %% [markdown]
# ## Calculate the average rating of Gaming and Non-Gaming apps

# %%
import pandas as pd
import  numpy as np
import  matplotlib.pyplot as plt
df= pd.read_csv('DataFiles/AppleStore.csv')
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
gaming =  df[df['prime_genre']=='Games']
print(type(gaming))
gaming.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Unnamed: 0         id                 track_name  size_bytes currency  \
# 0            1  281656475            PAC-MAN Premium   100788224      USD
# 5            6  283619399           Shanghai Mahjong    10485713      USD
# 9           10  284736660                Ms. PAC-MAN    70023168      USD
# 10          11  284791396  Solitaire by MobilityWare    49618944      USD
# 11          12  284815117           SCRABBLE Premium   227547136      USD
#
#     price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0    3.99             21292                26          4.0              4.5
# 5    0.99              8253              5516          4.0              4.0
# 9    3.99              7885                40          4.0              4.0
# 10   4.99             76720              4017          4.5              4.5
# 11   7.99            105776               166          3.5              2.5
#
# ...

# %%
s1 =gaming['user_rating'].sum()
avg_rating_gaming=s1/len(gaming)
print(s1)
print(avg_rating_gaming)
# Out:
# 14231.5
# 3.6850077679958573

# %%
nongaming =  df[df['prime_genre']!='Games']
print(type(nongaming))
nongaming.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0         id                                         track_name  \
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
# 6           7  283646709             PayPal - Send and request money safely
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 1   158578688      USD    0.0            161065                26
# 2   100524032      USD    0.0            188583              2822
# 3   128512000      USD    0.0            262241               649
# 4    92774400      USD    0.0            985920              5320
# 6   227795968      USD    0.0            119487               879
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
s2 = nongaming['user_rating'].sum()
avg_rating_nongaming= s2/len(nongaming)
print(s2)
print(avg_rating_nongaming)
# Out:
# 11152.0
# 3.343928035982009

# %%
# Draw Pie plot based on labels as  below Price category and values as count of each category apps  
- labels:

    - Price =0  - Free apps
    -Price <20 - Affordable apps
# Price<50 - Expensive apps
# Price >50 - Very expensive

# %%
free=len(df[df['price']==0])
print(free)
affordable=len(df[(df['price']>0) & (df['price']<20) ])
print(affordable)
expensive=len(df[(df['price']>20) & (df['price']<50) ])
print(expensive)
vexpensive=len(df[df['price']>50 ])
print(vexpensive)
# Out:
# 4056
# 3105
# 29
# 7

# %%
rating=[4056,29,3105,7]
apps=['Free Apps','Expensive Apps','Affordable Apps','Very Expensive Apps']
plt.pie(rating,labels=apps,shadow=True,startangle=90,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.show()
